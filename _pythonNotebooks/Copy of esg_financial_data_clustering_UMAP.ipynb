# %% [markdown]
# # 0. General Imports

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Deloitte Backup/Financial Data Clustering Paper/"

# %%
es600 = pd.read_csv(f"{path}230507_es600_final.csv")

# %% [markdown]
# # 1. Data Pre-Processing

# %%
es600.shape[0]
# Out:
# 7801

# %%
#filtering for derivedEmissions in the STOXX600 dataset
es600 = es600.loc[es600.derivedEmissions.notna()]

# %%
es600.shape[0]
# Out:
# 6239

# %%
#applying condition that 80% at least for one column must be non-null and drop the rest of columns
cond = es600.count() < es600.shape[0] * 0.8
drop_columns = es600.count()[cond].index.to_list()
es600 = es600.drop(columns = drop_columns)
drop_columns
# Out:
# ['Environmental Expenditures',
#  'Environmental Provisions',
#  'CO2e Indirect Emissions, Scope 3',
#  'Environmental R&D Expenditures',
#  'Direct Energy/Energy Purchased Direct',
#  'Direct Energy/Energy Produced Direct',
#  'Indirect Energy Use',
#  'researchAndDevelopment',
#  'shortTermInvestments',
#  'rnd/sales',
#  'capex/fixedAssets',
#  'sga/sales']

# %%
def encode_categorical_variables(data: pd.DataFrame, variables: list):

  end_encoded_df = pd.DataFrame()

  for variable in variables:

    encoded_df = pd.get_dummies(data[[variable]].copy())
    end_encoded_df = pd.concat([end_encoded_df,encoded_df], axis = 1)

  data = data.drop(columns = variables)
  data = pd.concat([data, end_encoded_df], axis=1)

  return data

# %%
data = encode_categorical_variables(data = es600.copy(), variables = ["econIdDesc","IncomeGroup"])

# %% [markdown]
# # 3. Conducting Initial Test of Clustering with UMAP

# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.3.0)
# Building wheels for collected packages: umap-learn
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=c5b88700823b4ea5de23d0c103afb65876e389ba1ca36cc08a4f9cb082aff5c9
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built umap-learn
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.11 umap-learn-0.5.5

# %%
import umap
import matplotlib.pyplot as plt
import seaborn as sns

# %%
len(data)
# Out:
# 6239

# %%
data.isna().sum().sort_values(ascending = False).head(25)
# Out:
# Energy Use Total                                             1096
# cogs/sales                                                    945
# grossMargin                                                   943
# grossProfit                                                   911
# capex/totalSales                                              829
# CO2 Equivalents Emission Indirect                             605
# CO2 Equivalents Emission Direct                               570
# capex/totalAssets                                             448
# propertyPlantEquipmentTotal                                   307
# totalAssets/commonEquity                                      141
# ebit/interest                                                 113
# Emission Reduction Objectives/Targets Emissions Reduction      91
# totalAssets/employee                                           91
# roa                                                            78
# sales/employee                                                 40
# employees                                                      35
# enterpriseValue                                                30
# commonStock                                                    25
# ebitda                                                         13
# operatingMargin                                                13
# Emission Reduction Processes/Policy Emissions Reduction         9
# cf/sales                                                        9
# capex                                                           8
# CO2 Equivalents Emission Total                                  4
# totalRevenue                                                    2
# dtype: int64

# %%
data = data.dropna()

# %%
data.head(1)
# Out:
#      OrgId  econId   OrgName_x  FisYear     Id_A4   OrgName_y  BusTRBCId  \
# 1  10836.0    54.0  Siemens AG     2009  @SIEME18  Siemens AG     5440.0
#
#    Emission Reduction Processes/Policy Emissions Reduction  \
# 1                                                1.0
#
#    Emission Reduction Objectives/Targets Emissions Reduction  \
# 1                                                1.0
#
#    derivedEmissions  CO2 Equivalents Emission Total  \
# 1         2574000.0                       2574000.0
#
#    CO2 Equivalents Emission Direct  CO2 Equivalents Emission Indirect  \
# 1                        1115000.0                          1459000.0
#
#    emissionIntensity  Energy Use Total  ESG SCORE  ESG Combined Score  \
# 1          22.943176        23800000.0    0.88308            0.774873
#
#    ESG Controversies Score  Resource Use Score  Emissions Score  \
# 1                 0.666667               0.925         0.977273
#
#    Environmental Innovation Score  Workforce Score  Human Rights Score  \
# 1                           0.775         0.982143            0.807692
#
#    Community Score  Product Responsibility Score  Management Score  \
# 1            0.875                      0.613636          0.993506
#
#    Shareholders Score  CSR Strategy Score   totalRevenue    totalAssets  \
# 1            0.967532            0.951613  112190.219438  138938.419204
#
#    employees   grossProfit  operatingIncome  earningsBeforeTax  \
# 1   405000.0  30452.697364      8699.934304        5695.061302
#
#    propertyPlantEquipmentTotal     totalDebt  totalLiabilities  commonStock  \
# 1                 40153.768119  28743.154418      94182.936171  4014.791352
#
#    netIncome        ebitda  enterpriseValue  totalAssets/commonEquity  \
# 1  3354.6853  12719.116605     63156.422093                   3.43898
#
#    ebit/interest  grossMargin  cf/sales  operatingMargin      roa  cogs/sales  \
# 1        6.69693     27.14381   9.35539          7.75463  2.97482    69.27372
#
#    sales/employee  totalAssets/employee  capex/totalAssets  capex/totalSales  \
# 1     189261.7284          226259.25926            3.19614           3.81339
#
#          capex ISOCountryCodeDerived                 Region       GDP PPP  \
# 1  4278.248313                   DEU  Europe & Central Asia  36842.916198
#
#    econIdDesc_Basic Materials  econIdDesc_Consumer Cyclicals  \
# 1                           0                              0
#
#    econIdDesc_Consumer Non-Cyclicals  econIdDesc_Energy  \
# 1                                  1                  0
#
#    econIdDesc_Financials  econIdDesc_Healthcare  econIdDesc_Industrials  \
# 1                      0                      0                       0
#
#    econIdDesc_Real Estate  econIdDesc_Technology  econIdDesc_Utilities  \
# 1                       0                      0                     0
#
#    IncomeGroup_High income  IncomeGroup_Upper middle income
# 1                        1                                0

# %%
data.to_csv("capstone_dataset.csv", index = False)

# %% [markdown]
# ## v1 - esg features

# %%
esg_features = ['derivedEmissions', 'emissionIntensity', 'Energy Use Total', 'ESG SCORE',
                'ESG Combined Score', 'ESG Controversies Score', 'Resource Use Score',
                'Emissions Score', 'Environmental Innovation Score', 'Workforce Score',
                'Human Rights Score', 'Community Score', 'Product Responsibility Score',
                'Management Score', 'Shareholders Score', 'CSR Strategy Score']

# %%
esg_data = data[esg_features]
esg_data = esg_data.replace([np.inf, -np.inf], np.nan)
esg_data = esg_data.dropna()
if esg_data.isna().any().any():
    print("There are NaN values in the DataFrame.")
else:
    print("No NaN values found.")
# Out:
# No NaN values found.
